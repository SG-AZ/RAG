# %%
# !pip install langchain-openai
# !pip install langchain
# !pip install langchain_community
# !pip install langchain_core
# !pip install gradio
# !pip install unstructured
# !pip install unstructured[pdf]
# !pip install Chromadb
# !pip install numpy==1.24.1py
# !pip install python-magic-bin
# Out:
# Requirement already satisfied: langchain-openai in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (0.2.2)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.9 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain-openai) (0.3.10)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain-openai) (1.51.2)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain-openai) (0.8.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain-core<0.4.0,>=0.3.9->langchain-openai) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain-core<0.4.0,>=0.3.9->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain-core<0.4.0,>=0.3.9->langchain-openai) (0.1.133)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain-core<0.4.0,>=0.3.9->langchain-openai) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain-core<0.4.0,>=0.3.9->langchain-openai) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain-core<0.4.0,>=0.3.9->langchain-openai) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain-core<0.4.0,>=0.3.9->langchain-openai) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (4.6.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (0.6.1)
# Requirement already satisfied: sniffio in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (4.66.5)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.9.11)
# Requirement already satisfied: requests>=2.26.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->langchain-openai) (3.10)
# Requirement already satisfied: certifi in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.9->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.9->langchain-openai) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.9->langchain-openai) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.9->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.9->langchain-openai) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.2.3)
# Requirement already satisfied: colorama in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.40.0->langchain-openai) (0.4.6)
# Requirement already satisfied: langchain in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (0.3.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain) (3.10.9)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.10 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain) (0.3.10)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain) (0.3.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain) (0.1.133)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.14.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain-core<0.4.0,>=0.3.10->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain-core<0.4.0,>=0.3.10->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain-core<0.4.0,>=0.3.10->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.6.0)
# Requirement already satisfied: httpcore==1.* in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.6)
# Requirement already satisfied: sniffio in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.10->langchain) (3.0.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Requirement already satisfied: langchain_community in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (0.3.2)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain_community) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain_community) (3.10.9)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: langchain<0.4.0,>=0.3.3 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain_community) (0.3.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.10 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain_community) (0.3.10)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain_community) (0.1.133)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain_community) (2.5.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain_community) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.14.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain<0.4.0,>=0.3.3->langchain_community) (0.3.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain<0.4.0,>=0.3.3->langchain_community) (2.9.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain-core<0.4.0,>=0.3.10->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain-core<0.4.0,>=0.3.10->langchain_community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain-core<0.4.0,>=0.3.10->langchain_community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from requests<3,>=2->langchain_community) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from requests<3,>=2->langchain_community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from requests<3,>=2->langchain_community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from requests<3,>=2->langchain_community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.1.1)
# Requirement already satisfied: anyio in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (4.6.0)
# Requirement already satisfied: httpcore==1.* in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (1.0.6)
# Requirement already satisfied: sniffio in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.10->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.3->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.3->langchain_community) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain_community) (0.2.0)
# Requirement already satisfied: langchain_core in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (0.3.10)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain_core) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain_core) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain_core) (0.1.133)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain_core) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain_core) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain_core) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langchain_core) (4.12.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain_core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain_core) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain_core) (3.10.7)
# Requirement already satisfied: requests<3,>=2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain_core) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain_core) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (2.23.4)
# Requirement already satisfied: anyio in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_core) (4.6.0)
# Requirement already satisfied: certifi in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_core) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_core) (1.0.6)
# Requirement already satisfied: idna in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_core) (3.10)
# Requirement already satisfied: sniffio in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_core) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_core) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain_core) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain_core) (2.2.3)
# Requirement already satisfied: gradio in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (5.0.1)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (4.6.0)
# Requirement already satisfied: fastapi<1.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (0.115.0)
# Requirement already satisfied: ffmpy in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (0.4.0)
# Requirement already satisfied: gradio-client==1.4.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (1.4.0)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (0.27.2)
# Requirement already satisfied: huggingface-hub>=0.25.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (0.25.2)
# Requirement already satisfied: jinja2<4.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (2.1.5)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (3.10.7)
# Requirement already satisfied: packaging in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (10.4.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (2.9.2)
# Requirement already satisfied: pydub in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (0.0.12)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (0.6.9)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (0.12.5)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio) (0.31.1)
# Requirement already satisfied: fsspec in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio-client==1.4.0->gradio) (2024.9.0)
# Requirement already satisfied: websockets<13.0,>=10.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from gradio-client==1.4.0->gradio) (12.0)
# Requirement already satisfied: idna>=2.8 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from fastapi<1.0->gradio) (0.38.6)
# Requirement already satisfied: certifi in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx>=0.24.1->gradio) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (3.16.1)
# Requirement already satisfied: requests in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (4.66.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from pydantic>=2.0->gradio) (2.23.4)
# Requirement already satisfied: click>=8.0.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.9.2)
# Requirement already satisfied: colorama in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from requests->huggingface-hub>=0.25.1->gradio) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from requests->huggingface-hub>=0.25.1->gradio) (2.2.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: unstructured in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (0.15.14)
# Requirement already satisfied: chardet in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured) (5.2.0)
# Requirement already satisfied: filetype in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured) (5.3.0)
# Requirement already satisfied: nltk in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: tabulate in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured) (0.9.0)
# Requirement already satisfied: requests in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured) (4.12.3)
# Requirement already satisfied: emoji in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured) (2.14.0)
# Requirement already satisfied: dataclasses-json in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured) (0.6.7)
# Requirement already satisfied: python-iso639 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured) (2024.4.27)
# Requirement already satisfied: langdetect in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy<2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured) (1.26.4)
# Requirement already satisfied: rapidfuzz in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured) (3.10.0)
# Requirement already satisfied: backoff in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured) (4.12.2)
# Requirement already satisfied: unstructured-client in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured) (0.26.0)
# Requirement already satisfied: wrapt in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured) (1.16.0)
# Requirement already satisfied: tqdm in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured) (4.66.5)
# Requirement already satisfied: psutil in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured) (6.0.0)
# Requirement already satisfied: python-oxmsg in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured) (0.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from beautifulsoup4->unstructured) (2.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from dataclasses-json->unstructured) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langdetect->unstructured) (1.16.0)
# Requirement already satisfied: click in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from nltk->unstructured) (8.1.7)
# Requirement already satisfied: joblib in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from nltk->unstructured) (2024.9.11)
# Requirement already satisfied: olefile in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from requests->unstructured) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from requests->unstructured) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from requests->unstructured) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from requests->unstructured) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from tqdm->unstructured) (0.4.6)
# Requirement already satisfied: cryptography>=3.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured-client->unstructured) (43.0.1)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.2.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured-client->unstructured) (0.2.0)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured-client->unstructured) (0.27.2)
# Requirement already satisfied: jsonpath-python<2.0.0,>=1.0.6 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured-client->unstructured) (1.0.6)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: pydantic<2.10.0,>=2.9.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured-client->unstructured) (2.9.2)
# Requirement already satisfied: pypdf>=4.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured-client->unstructured) (5.0.1)
# Requirement already satisfied: python-dateutil==2.8.2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured-client->unstructured) (2.8.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.17.1)
# Requirement already satisfied: anyio in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.6.0)
# Requirement already satisfied: httpcore==1.* in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.0.6)
# Requirement already satisfied: sniffio in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (24.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from pydantic<2.10.0,>=2.9.0->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from pydantic<2.10.0,>=2.9.0->unstructured-client->unstructured) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.0.0)
# Requirement already satisfied: pycparser in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured) (2.22)
# Requirement already satisfied: unstructured[pdf] in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (0.15.14)
# Requirement already satisfied: chardet in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (5.2.0)
# Requirement already satisfied: filetype in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (0.4.27)
# Requirement already satisfied: lxml in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (5.3.0)
# Requirement already satisfied: nltk in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (3.9.1)
# Requirement already satisfied: tabulate in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (0.9.0)
# Requirement already satisfied: requests in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (4.12.3)
# Requirement already satisfied: emoji in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (2.14.0)
# Requirement already satisfied: dataclasses-json in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (0.6.7)
# Requirement already satisfied: python-iso639 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (2024.4.27)
# Requirement already satisfied: langdetect in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (1.0.9)
# Requirement already satisfied: numpy<2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (1.26.4)
# Requirement already satisfied: rapidfuzz in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (3.10.0)
# Requirement already satisfied: backoff in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (2.2.1)
# Requirement already satisfied: typing-extensions in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (4.12.2)
# Requirement already satisfied: unstructured-client in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (0.26.0)
# Requirement already satisfied: wrapt in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (1.16.0)
# Requirement already satisfied: tqdm in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (4.66.5)
# Requirement already satisfied: psutil in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (6.0.0)
# Requirement already satisfied: python-oxmsg in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (0.0.1)
# Requirement already satisfied: onnx in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (1.17.0)
# Requirement already satisfied: pdf2image in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (1.17.0)
# Requirement already satisfied: pdfminer.six in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (20231228)
# Requirement already satisfied: pikepdf in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (9.3.0)
# Requirement already satisfied: pi-heif in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (0.18.0)
# Requirement already satisfied: pypdf in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (5.0.1)
# Requirement already satisfied: google-cloud-vision in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (3.7.4)
# Requirement already satisfied: effdet in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (0.4.1)
# Requirement already satisfied: unstructured-inference==0.7.36 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (0.7.36)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured[pdf]) (0.3.13)
# Requirement already satisfied: layoutparser in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured-inference==0.7.36->unstructured[pdf]) (0.3.4)
# Requirement already satisfied: python-multipart in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured-inference==0.7.36->unstructured[pdf]) (0.0.12)
# Requirement already satisfied: huggingface-hub in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured-inference==0.7.36->unstructured[pdf]) (0.25.2)
# Requirement already satisfied: opencv-python!=4.7.0.68 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured-inference==0.7.36->unstructured[pdf]) (4.10.0.84)
# Requirement already satisfied: onnxruntime>=1.17.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured-inference==0.7.36->unstructured[pdf]) (1.19.2)
# Requirement already satisfied: matplotlib in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured-inference==0.7.36->unstructured[pdf]) (3.9.2)
# Requirement already satisfied: torch in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured-inference==0.7.36->unstructured[pdf]) (2.4.1)
# Requirement already satisfied: timm in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured-inference==0.7.36->unstructured[pdf]) (1.0.9)
# Requirement already satisfied: transformers>=4.25.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured-inference==0.7.36->unstructured[pdf]) (4.45.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured.pytesseract>=0.3.12->unstructured[pdf]) (24.1)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from unstructured.pytesseract>=0.3.12->unstructured[pdf]) (10.4.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from beautifulsoup4->unstructured[pdf]) (2.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from dataclasses-json->unstructured[pdf]) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from dataclasses-json->unstructured[pdf]) (0.9.0)
# Requirement already satisfied: torchvision in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from effdet->unstructured[pdf]) (0.19.1)
# Requirement already satisfied: pycocotools>=2.0.2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from effdet->unstructured[pdf]) (2.0.8)
# Requirement already satisfied: omegaconf>=2.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from effdet->unstructured[pdf]) (2.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[pdf]) (2.21.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from google-cloud-vision->unstructured[pdf]) (2.35.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from google-cloud-vision->unstructured[pdf]) (1.24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from google-cloud-vision->unstructured[pdf]) (4.25.5)
# Requirement already satisfied: six in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from langdetect->unstructured[pdf]) (1.16.0)
# Requirement already satisfied: click in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from nltk->unstructured[pdf]) (8.1.7)
# Requirement already satisfied: joblib in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from nltk->unstructured[pdf]) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from nltk->unstructured[pdf]) (2024.9.11)
# ...
# Using cached protobuf-5.28.2-cp310-abi3-win_amd64.whl (431 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
# Successfully installed protobuf-5.28.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-proto 1.27.0 requires protobuf<5.0,>=3.19, but you have protobuf 5.28.2 which is incompatible.
# Requirement already satisfied: Chromadb in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (0.5.12)
# Requirement already satisfied: build>=1.0.3 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (2.9.2)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (0.115.0)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->Chromadb) (0.31.1)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (3.7.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (1.19.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (1.27.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (0.20.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (1.66.2)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (4.2.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (0.12.5)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (31.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (3.10.7)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from Chromadb) (13.9.2)
# Requirement already satisfied: packaging>=19.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from build>=1.0.3->Chromadb) (24.1)
# Requirement already satisfied: pyproject_hooks in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from build>=1.0.3->Chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from build>=1.0.3->Chromadb) (0.4.6)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from fastapi>=0.95.2->Chromadb) (0.38.6)
# Requirement already satisfied: anyio in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx>=0.27.0->Chromadb) (4.6.0)
# Requirement already satisfied: certifi in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx>=0.27.0->Chromadb) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx>=0.27.0->Chromadb) (1.0.6)
# Requirement already satisfied: idna in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx>=0.27.0->Chromadb) (3.10)
# Requirement already satisfied: sniffio in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpx>=0.27.0->Chromadb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->Chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from kubernetes>=28.1.0->Chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from kubernetes>=28.1.0->Chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from kubernetes>=28.1.0->Chromadb) (2.35.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from kubernetes>=28.1.0->Chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from kubernetes>=28.1.0->Chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from kubernetes>=28.1.0->Chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from kubernetes>=28.1.0->Chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from kubernetes>=28.1.0->Chromadb) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from kubernetes>=28.1.0->Chromadb) (0.9)
# Requirement already satisfied: coloredlogs in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from onnxruntime>=1.14.1->Chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from onnxruntime>=1.14.1->Chromadb) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from onnxruntime>=1.14.1->Chromadb) (5.28.2)
# Requirement already satisfied: sympy in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from onnxruntime>=1.14.1->Chromadb) (1.13.3)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from opentelemetry-api>=1.2.0->Chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from opentelemetry-api>=1.2.0->Chromadb) (8.4.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->Chromadb) (1.65.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->Chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->Chromadb) (1.27.0)
# Collecting protobuf (from onnxruntime>=1.14.1->Chromadb)
#   Using cached protobuf-4.25.5-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->Chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->Chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->Chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->Chromadb) (0.48b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->Chromadb) (75.1.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->Chromadb) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->Chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from posthog>=2.4.0->Chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from posthog>=2.4.0->Chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from pydantic>=1.9->Chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from pydantic>=1.9->Chromadb) (2.23.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from rich>=10.11.0->Chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from rich>=10.11.0->Chromadb) (2.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from tokenizers>=0.13.2->Chromadb) (0.25.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from typer>=0.9.0->Chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from typer>=0.9.0->Chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->Chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->Chromadb) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->Chromadb) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->Chromadb) (12.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->Chromadb) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->Chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->Chromadb) (4.9)
# Requirement already satisfied: filelock in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->Chromadb) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->Chromadb) (2024.9.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.2.0->Chromadb) (3.20.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->Chromadb) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from requests->kubernetes>=28.1.0->Chromadb) (3.4.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->Chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from sympy->onnxruntime>=1.14.1->Chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->Chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->Chromadb) (0.6.1)
# Using cached protobuf-4.25.5-cp310-abi3-win_amd64.whl (413 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.28.2
#     Uninstalling protobuf-5.28.2:
#       Successfully uninstalled protobuf-5.28.2
# Successfully installed protobuf-4.25.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.66.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.5 which is incompatible.
# ERROR: Invalid requirement: 'numpy==1.24.1py': Expected end or semicolon (after version specifier)
#     numpy==1.24.1py
#          ~~~~~~~~^

# %%
# !pip show langchain
# !pip show openai
# Out:
# Name: langchain
# Version: 0.3.3
# Summary: Building applications with LLMs through composability
# Home-page: https://github.com/langchain-ai/langchain
# Author:
# Author-email:
# License: MIT
# Location: C:\Users\sghimire\RAG_Logic_obfuscation\myEnv\Lib\site-packages
# Requires: aiohttp, langchain-core, langchain-text-splitters, langsmith, numpy, pydantic, PyYAML, requests, SQLAlchemy, tenacity
# Required-by: langchain-community
# Name: openai
# Version: 1.51.2
# Summary: The official Python library for the openai API
# Home-page: https://github.com/openai/openai-python
# Author:
# Author-email: OpenAI <support@openai.com>
# License:
# Location: C:\Users\sghimire\RAG_Logic_obfuscation\myEnv\Lib\site-packages
# Requires: anyio, distro, httpx, jiter, pydantic, sniffio, tqdm, typing-extensions
# Required-by: langchain-openai

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\sghimire\RAG_Logic_obfuscation\myEnv\Scripts\python.exe

# %%
import os
import json
from langchain_openai import ChatOpenAI
from langchain_community.document_loaders import UnstructuredFileLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain.schema.runnable import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import (
    ChatPromptTemplate,
    FewShotChatMessagePromptTemplate,
)
from operator import itemgetter

# %%
# OpenAI API Key from collab secret
credentials ={}
try:
    with open('openai_api_key.json')as file:
        credentials =  json.load(file)
except FileNotFoundError:
    print("Error :openai_api_key.json not found")
print(credentials)
OPENAI_API_KEY = credentials['key']
print(OPENAI_API_KEY)
# Out:
# {'key': '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'}
# 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

# %%
# Out:
# Requirement already satisfied: python-magic-bin in c:\users\sghimire\rag_logic_obfuscation\myenv\lib\site-packages (0.4.14)

# %%
# initializing the LLM
llm = ChatOpenAI(
    openai_api_key=OPENAI_API_KEY,
    model_name="gpt-4",
)

# %%
print("Loading Data")
loader = UnstructuredFileLoader('./Knowledge.txt')
raw_doc = loader.load()
# Out:
# Loading Data
# C:\Users\sghimire\AppData\Local\Temp\ipykernel_55312\2139289733.py:2: LangChainDeprecationWarning: The class `UnstructuredFileLoader` was deprecated in LangChain 0.2.8 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-unstructured package and should be used instead. To use it run `pip install -U :class:`~langchain-unstructured` and import as `from :class:`~langchain_unstructured import UnstructuredLoader``.
#   loader = UnstructuredFileLoader('./Knowledge.txt')

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\sghimire\RAG_Logic_obfuscation\myEnv\Scripts\python.exe

# %%
import sys
import ctypes
import sqlite3
print(sqlite3.sqlite_version)
dll_location = ctypes.util.find_library('sqlite3')
print(f"SQLite3 DLL Location: {dll_location}")
# Out:
# 3.45.3
# SQLite3 DLL Location: C:\sqlite\sqlite3.dll

# %%
import sqlite3
import inspect

# Get the file path of the sqlite3 module
sqlite3_location = inspect.getfile(sqlite3)
print(f"SQLite3 module is located at: {sqlite3_location}")
# Out:
# SQLite3 module is located at: C:\Users\sghimire\AppData\Local\Programs\Python\Python312\Lib\sqlite3\__init__.py

# %%
# segmenting the document into segments

text_splitter = CharacterTextSplitter(chunk_size=300, chunk_overlap=0)
texts = text_splitter.split_documents(raw_doc)
# Out:
# Created a chunk of size 630, which is longer than the specified 300
# Created a chunk of size 533, which is longer than the specified 300
# Created a chunk of size 508, which is longer than the specified 300
# Created a chunk of size 857, which is longer than the specified 300
# Created a chunk of size 1036, which is longer than the specified 300
# Created a chunk of size 507, which is longer than the specified 300
# Created a chunk of size 353, which is longer than the specified 300
# Created a chunk of size 1045, which is longer than the specified 300
# Created a chunk of size 303, which is longer than the specified 300
# Created a chunk of size 442, which is longer than the specified 300
# Created a chunk of size 1279, which is longer than the specified 300
# Created a chunk of size 476, which is longer than the specified 300
# Created a chunk of size 606, which is longer than the specified 300
# Created a chunk of size 718, which is longer than the specified 300
# Created a chunk of size 359, which is longer than the specified 300
# Created a chunk of size 1135, which is longer than the specified 300
# Created a chunk of size 1015, which is longer than the specified 300
# Created a chunk of size 741, which is longer than the specified 300
# Created a chunk of size 1381, which is longer than the specified 300
# Created a chunk of size 2695, which is longer than the specified 300
# Created a chunk of size 1560, which is longer than the specified 300
# Created a chunk of size 757, which is longer than the specified 300
# Created a chunk of size 383, which is longer than the specified 300
# Created a chunk of size 1665, which is longer than the specified 300
# Created a chunk of size 798, which is longer than the specified 300
# Created a chunk of size 316, which is longer than the specified 300
# Created a chunk of size 1614, which is longer than the specified 300
# Created a chunk of size 447, which is longer than the specified 300
# Created a chunk of size 638, which is longer than the specified 300
# Created a chunk of size 915, which is longer than the specified 300
# Created a chunk of size 954, which is longer than the specified 300
# Created a chunk of size 1578, which is longer than the specified 300
# Created a chunk of size 1614, which is longer than the specified 300
# Created a chunk of size 1492, which is longer than the specified 300
# Created a chunk of size 1202, which is longer than the specified 300
# Created a chunk of size 3568, which is longer than the specified 300
# Created a chunk of size 3963, which is longer than the specified 300
# Created a chunk of size 1549, which is longer than the specified 300
# Created a chunk of size 632, which is longer than the specified 300
# Created a chunk of size 679, which is longer than the specified 300
# Created a chunk of size 1798, which is longer than the specified 300
# Created a chunk of size 818, which is longer than the specified 300
# Created a chunk of size 626, which is longer than the specified 300
# Created a chunk of size 1021, which is longer than the specified 300
# Created a chunk of size 1014, which is longer than the specified 300
# Created a chunk of size 391, which is longer than the specified 300
# Created a chunk of size 651, which is longer than the specified 300
# Created a chunk of size 563, which is longer than the specified 300
# Created a chunk of size 1403, which is longer than the specified 300
# Created a chunk of size 1148, which is longer than the specified 300
# Created a chunk of size 442, which is longer than the specified 300
# Created a chunk of size 2401, which is longer than the specified 300
# Created a chunk of size 956, which is longer than the specified 300
# Created a chunk of size 500, which is longer than the specified 300
# Created a chunk of size 327, which is longer than the specified 300
# Created a chunk of size 536, which is longer than the specified 300
# Created a chunk of size 338, which is longer than the specified 300
# Created a chunk of size 1708, which is longer than the specified 300
# Created a chunk of size 465, which is longer than the specified 300
# Created a chunk of size 304, which is longer than the specified 300
# Created a chunk of size 1280, which is longer than the specified 300
# Created a chunk of size 1320, which is longer than the specified 300
# Created a chunk of size 506, which is longer than the specified 300
# Created a chunk of size 570, which is longer than the specified 300
# Created a chunk of size 437, which is longer than the specified 300
# Created a chunk of size 995, which is longer than the specified 300
# Created a chunk of size 564, which is longer than the specified 300
# Created a chunk of size 390, which is longer than the specified 300
# Created a chunk of size 764, which is longer than the specified 300
# Created a chunk of size 987, which is longer than the specified 300
# Created a chunk of size 719, which is longer than the specified 300
# Created a chunk of size 1000, which is longer than the specified 300
# Created a chunk of size 627, which is longer than the specified 300
# Created a chunk of size 837, which is longer than the specified 300
# Created a chunk of size 819, which is longer than the specified 300
# Created a chunk of size 425, which is longer than the specified 300
# Created a chunk of size 381, which is longer than the specified 300
# Created a chunk of size 721, which is longer than the specified 300
# Created a chunk of size 360, which is longer than the specified 300
# Created a chunk of size 556, which is longer than the specified 300
# Created a chunk of size 462, which is longer than the specified 300
# Created a chunk of size 1909, which is longer than the specified 300
# Created a chunk of size 1470, which is longer than the specified 300
# Created a chunk of size 1954, which is longer than the specified 300
# Created a chunk of size 2727, which is longer than the specified 300
# Created a chunk of size 3359, which is longer than the specified 300
# Created a chunk of size 572, which is longer than the specified 300
# Created a chunk of size 1663, which is longer than the specified 300
# Created a chunk of size 474, which is longer than the specified 300
# Created a chunk of size 611, which is longer than the specified 300
# Created a chunk of size 607, which is longer than the specified 300
# Created a chunk of size 450, which is longer than the specified 300
# Created a chunk of size 656, which is longer than the specified 300
# Created a chunk of size 1808, which is longer than the specified 300
# Created a chunk of size 1419, which is longer than the specified 300
# Created a chunk of size 1859, which is longer than the specified 300
# Created a chunk of size 986, which is longer than the specified 300
# Created a chunk of size 670, which is longer than the specified 300
# Created a chunk of size 585, which is longer than the specified 300
# Created a chunk of size 654, which is longer than the specified 300
# Created a chunk of size 395, which is longer than the specified 300
# Created a chunk of size 2078, which is longer than the specified 300
# Created a chunk of size 1348, which is longer than the specified 300
# Created a chunk of size 1182, which is longer than the specified 300
# Created a chunk of size 1667, which is longer than the specified 300
# Created a chunk of size 1093, which is longer than the specified 300
# Created a chunk of size 2306, which is longer than the specified 300
# Created a chunk of size 1406, which is longer than the specified 300
# Created a chunk of size 1205, which is longer than the specified 300
# Created a chunk of size 1402, which is longer than the specified 300
# Created a chunk of size 526, which is longer than the specified 300
# Created a chunk of size 458, which is longer than the specified 300
# Created a chunk of size 1383, which is longer than the specified 300
# Created a chunk of size 422, which is longer than the specified 300
# Created a chunk of size 405, which is longer than the specified 300
# Created a chunk of size 891, which is longer than the specified 300
# Created a chunk of size 979, which is longer than the specified 300
# Created a chunk of size 439, which is longer than the specified 300
# Created a chunk of size 340, which is longer than the specified 300
# Created a chunk of size 618, which is longer than the specified 300
# Created a chunk of size 615, which is longer than the specified 300
# Created a chunk of size 385, which is longer than the specified 300
# Created a chunk of size 680, which is longer than the specified 300
# Created a chunk of size 496, which is longer than the specified 300
# Created a chunk of size 661, which is longer than the specified 300
# Created a chunk of size 548, which is longer than the specified 300
# Created a chunk of size 322, which is longer than the specified 300
# Created a chunk of size 760, which is longer than the specified 300
# Created a chunk of size 383, which is longer than the specified 300
# Created a chunk of size 1590, which is longer than the specified 300
# Created a chunk of size 686, which is longer than the specified 300
# Created a chunk of size 349, which is longer than the specified 300
# Created a chunk of size 809, which is longer than the specified 300
# Created a chunk of size 323, which is longer than the specified 300
# Created a chunk of size 443, which is longer than the specified 300
# Created a chunk of size 768, which is longer than the specified 300
# Created a chunk of size 718, which is longer than the specified 300
# Created a chunk of size 565, which is longer than the specified 300
# Created a chunk of size 515, which is longer than the specified 300
# Created a chunk of size 669, which is longer than the specified 300
# Created a chunk of size 2981, which is longer than the specified 300
# Created a chunk of size 1863, which is longer than the specified 300
# Created a chunk of size 2683, which is longer than the specified 300
# Created a chunk of size 2804, which is longer than the specified 300
# Created a chunk of size 2947, which is longer than the specified 300
# Created a chunk of size 1709, which is longer than the specified 300
# Created a chunk of size 362, which is longer than the specified 300
# Created a chunk of size 936, which is longer than the specified 300
# Created a chunk of size 457, which is longer than the specified 300
# Created a chunk of size 2951, which is longer than the specified 300
# Created a chunk of size 1450, which is longer than the specified 300
# Created a chunk of size 347, which is longer than the specified 300
# Created a chunk of size 572, which is longer than the specified 300
# Created a chunk of size 1081, which is longer than the specified 300
# Created a chunk of size 472, which is longer than the specified 300
# Created a chunk of size 794, which is longer than the specified 300
# Created a chunk of size 496, which is longer than the specified 300
# Created a chunk of size 555, which is longer than the specified 300
# Created a chunk of size 469, which is longer than the specified 300
# Created a chunk of size 353, which is longer than the specified 300
# Created a chunk of size 1122, which is longer than the specified 300
# Created a chunk of size 301, which is longer than the specified 300
# Created a chunk of size 338, which is longer than the specified 300
# Created a chunk of size 312, which is longer than the specified 300
# Created a chunk of size 2148, which is longer than the specified 300
# Created a chunk of size 393, which is longer than the specified 300
# Created a chunk of size 464, which is longer than the specified 300
# Created a chunk of size 319, which is longer than the specified 300
# Created a chunk of size 781, which is longer than the specified 300
# Created a chunk of size 624, which is longer than the specified 300
# Created a chunk of size 896, which is longer than the specified 300
# Created a chunk of size 387, which is longer than the specified 300
# Created a chunk of size 629, which is longer than the specified 300
# Created a chunk of size 683, which is longer than the specified 300
# Created a chunk of size 401, which is longer than the specified 300
# Created a chunk of size 384, which is longer than the specified 300
# Created a chunk of size 324, which is longer than the specified 300
# Created a chunk of size 400, which is longer than the specified 300
# Created a chunk of size 358, which is longer than the specified 300

# %%
# Document Embedding with Chromadb

embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)
docsearch = Chroma.from_documents(texts, embeddings)
# Out:
# C:\Users\sghimire\AppData\Local\Temp\ipykernel_55312\2331640418.py:3: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)

# %%
print("Loading Data")
loader1 = UnstructuredFileLoader('./Knowlege1.txt')
raw_doc1 = loader1.load()
text_splitter1 =CharacterTextSplitter(
    separator = "##############################################################################################",
    chunk_size= 2,
    chunk_overlap = 1,
    length_function = len
)
texts1 = text_splitter1.split_documents(raw_doc1)
for idx, text in enumerate(texts1):
    print(f"Text Chunk {idx+1}:")
    print(text.page_content)
# Out:
# Created a chunk of size 9, which is longer than the specified 2
# Created a chunk of size 8, which is longer than the specified 2
# Loading Data
# Text Chunk 1:
# apple
# Text Chunk 2:
# ball
# Text Chunk 3:
# Cat

# %%
# Connection to query with Chroma indexing using a retriever
retriever = docsearch.as_retriever(
    search_type="similarity",
    search_kwargs={'k':4}
)

# Function to add all docs returned by retriever

def format_docs(docs):
  return "\n\n".join(doc.page_content for doc in docs)

# %%
docs = retriever.get_relevant_documents("tell me about subscription term")
for d in docs:
  print(d.page_content)

# %%
few_shot_examples = [
{"input":"Could you please clarify the terms outlined in section 3.2 of the contract?",
"output":"Certainly, I will provide clarification on the terms in section 3.2."},
{"input":"We are interested in extending the payment deadline to 30 days instead of the current 15 days. Additionally, we would like to add a clause regarding late payment penalties.",
"output":"Our request is to extend the payment deadline to 30 days and include a clause on late payment penalties."},
{"input":"""The current indemnification clause seems too broad. We would like to narrow it down to cover only direct damages and exclude consequential damages.
Additionally, we propose including a dispute resolution clause specifying arbitration as the preferred method of resolving disputes.""",
"output":"""We suggest revising the indemnification clause to limit it to covering direct damages and excluding consequential damages.
Furthermore, we recommend adding a dispute resolution clause that specifies arbitration as the preferred method of resolving disputes."""},
{"input":"I believe the proposed changes are acceptable.",
"output":"Thank you for your feedback. I will proceed with implementing the proposed changes."}
]

few_shot_template = ChatPromptTemplate.from_messages(
    [
        ("human", "{input}"),
        ("ai", "{output}")
    ]
)

few_shot_prompt = FewShotChatMessagePromptTemplate(
    example_prompt=few_shot_template,
    examples=few_shot_examples,
)

print(few_shot_prompt.format())

# %%
# Creating prompt and LCEL
negotiate_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a contract negotiation expert. Do your best to negotiate toward the target term and start with lower term then slowly increase with the supplier.  Reply up to three sentences as it is for chat purpose."),
    few_shot_prompt,
    ("user", "{question}"),
    ("user", "{context}")
])

# Langchain Expression Language to call our LLM using the prompt template above
# RAG chain
negotiate_chain = (
    {"context": itemgetter("question") | retriever | format_docs,
     "question": itemgetter("question")}
    | negotiate_prompt
    | llm
    | StrOutputParser()
    )

# %%
negotiate_chain.invoke({"question":"but I would like to add the term that SailPoint will be given the opportunity to cure the faulty or failing SaaS Services within 30 days of notice to SailPoint of the problem.  Also, we can do net 60."})
